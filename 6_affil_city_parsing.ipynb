# %%
import pandas as pd
import numpy as np
import ast
from tqdm import tqdm
import sys
import time

from flashgeotext.geotext import GeoText
from geopy.geocoders import Nominatim

# %%
articles = pd.read_csv('data/inclusions.csv', index_col=0)

# %%
articles.authors = articles.authors.apply(lambda x: ast.literal_eval(x) if type(x) == str else x)
articles.author_affils = articles.author_affils.apply(lambda x: ast.literal_eval(x) if type(x) == str else x)
articles.keywords = articles.keywords.apply(lambda x: ast.literal_eval(x) if type(x) == str else x)
articles.references_pmids = articles.references_pmids.apply(lambda x: ast.literal_eval(x) if type(x) == str else x)
articles.mesh_terms = articles.mesh_terms.apply(lambda x: ast.literal_eval(x) if type(x) == str else x)

# %%
articles['affil_countries'] = np.nan
articles['affil_countries'] = articles['affil_countries'].astype(object)
articles['affil_countries_unique'] = np.nan
articles['affil_countries_unique'] = articles['affil_countries'].astype(object)
articles['affil_first_country'] = np.nan
articles['affil_last_country'] = np.nan

# %%
def find_affil_countries(affils: list, retry_count = 5):
    
    geolocator = Nominatim(user_agent='health_ai_scraper')
    geotext = GeoText()
    
    if affils == affils: # Check to make sure not NaN
        country_list = []
        location = None
        
        last_affil = None
        last_country = None
        
        try_count = 0
    
        for affil in affils:
            if affil == last_affil: # Check to see if we've seen this before and take a shortcut if we have
                country_list = country_list + last_country

            else:
                while try_count < retry_count:
                    try:
                        last_affil = affil # Set that we've examined this affil
                
                        countries = [*geotext.extract(input_text=affil, span_info=True)['cities'].keys()] # Look for countries
                
                        if (len(countries) == 0): # If we dont find a country look harder
                            cities = [*geotext.extract(input_text=affil, span_info=True)['cities'].keys()]
                            if len(cities) > 0:
                                location = geolocator.geocode(cities[-1])
                            else:
                                location = geolocator.geocode(' '.join(affil.split(" ")[-2:]))
                                if location == None:
                                    location = geolocator.geocode(affil)
                                    if location == None:
                                        tqdm.write("Can't find a country for:")
                                        tqdm.write(affil)
                                        country_list = country_list + [np.nan]
                                        last_country = [np.nan]
                            
                        else: # If we do find a country then att it to the list and set the last_country variable
                            country_list = country_list + countries
                            last_country = countries
        
                        if location != None: # If we found an address using the other search techniques
                            countries = [*geotext.extract(input_text=location.address, span_info=True)['countries'].keys()]
                            country_list = country_list + countries
                            last_country = countries
                            
                        break
                            
                    except:
                        try_count += 1
                        tqdm.write(f"Error parsing {affil}, trying again for a maximum of 5 times.")
                        
    else: # If the affil is NaN then make the country list NaN
        country_list = [np.nan]
        
    unique_countries = list(set(country_list))
    first_affil_country = country_list[0]
    last_affil_country = country_list[-1]    
        
    return country_list, unique_countries, first_affil_country, last_affil_country

# %%
def parse_affil_countries(df, max_consecutive_failures = 5, filter_column = 'include'):
    
    consecutive_failures = 0
    
    country_df = df.copy()
    
    country_df['affil_countries'] = np.nan
    country_df['affil_countries_unique'] = np.nan
    country_df['affil_countries_first'] = np.nan
    country_df['affil_countries_last'] = np.nan
    
    with tqdm(total=country_df.shape[0], file=sys.stdout) as pbar:
        for row in country_df[country_df[filter_column] == 1].itertuples():

            try:
                affils = row.author_affils
    
                country_list, unique_countries, first_affil_country, last_affil_country = find_affil_countries(affils)
    
                country_df.loc[row.Index, 'affil_countries'] = str(country_list)
                country_df.loc[row.Index, 'affil_countries_unique'] = str(list(set(country_list)))
                country_df.loc[row.Index, 'affil_countries_first'] = country_list[0]
                country_df.loc[row.Index, 'affil_countries_last'] = country_list[-1]
            
                consecutive_failures = 0
        
            except Exception as e:
                tqdm.write(e)
                consecutive_failures += 1
                if consecutive_failures >=  max_consecutive_failures:
                    tqdm.write("Failed too many in a row, something is broken, stopping and returning possibly partially labelled DF...")
                    break
                
            pbar.update(1)
            
    country_df.replace("[nan]", np.nan, inplace=True)
            
    return country_df

# %%
consecutive_failures = 0

with tqdm(total=articles.shape[0], file=sys.stdout) as pbar:
    for row in articles.itertuples():

        try:
            affils = row.author_affils
    
            country_list, unique_countries, first_affil_country, last_affil_country = find_affil_countries(affils)
    
            articles.loc[row.Index, 'affil_countries'] = str(country_list)
            articles.loc[row.Index, 'affil_countries_unique'] = str(list(set(country_list)))
            articles.loc[row.Index, 'affil_first_country'] = country_list[0]
            articles.loc[row.Index, 'affil_last_country'] = country_list[-1]
            
            consecutive_failures = 0
        
        except:
            consecutive_failures += 1
            if consecutive_failures > 5:
                print("Failed too many in a row, something is broken, stopping...")
                break
            time.sleep(1)
                
        pbar.update(1)
# Out:
# Can't find a country for:
# West Hertfordshire Hospitals NHS Trust.
# Can't find a country for:
# Institute for Bio-Economy and Agri-Technology, Center for Research and Technology Hellas, 38333, Greece. Electronic address: d.tsaopoulos@certh.gr.
# Can't find a country for:
# DERMiSCAN, Brazil. Electronic address: renata.bitar@dermiscan.ch.
# Can't find a country for:
# Biodesix, United States. Electronic address: thomas.campbell@biodesix.com.
# Can't find a country for:
# Department of Radiology, the People's Hospital of Guangxi Zhuang Autonomous Region, 530021 Guangxi, China. Electronic address: demaodeng@163.com.
# Can't find a country for:
# Department of Neurology, Academic Medical Center, the Netherlands (A.W., Y.B.W.E.M.R.).
# Can't find a country for:
# Department of Computer Technology, Technical Sciences Vocational School, Fırat UniversityElazig, Turkey. Electronic address: mtogacar@firat.edu.tr.
# Can't find a country for:
# KI Research Institute, Kfar Malal, Israel. guy@kinstitute.org.il.
# Can't find a country for:
# Acute Care Surgery and General Surgery, Hamad Medical Corporation, Qatar.
# Can't find a country for:
# Division of Rheumatology, Allergy and Immunology, Chang Gung Memorial Hospital, Taoyuan, Taiwan. zandis@gmail.com.
# Can't find a country for:
# Clinical Medicine and Surgery (R.C.) renato.cuocolo@unina.it.
# Can't find a country for:
# Electrical Engineering and Information Technology (G.P., M.Q.).
# Can't find a country for:
# Dawnlight Inc., China. Electronic address: nan@dawnlight.com.
# Can't find a country for:
# Dawnlight Inc., China. Electronic address: liyu@dawnlight.com.
# Can't find a country for:
# Dawnlight Inc., China. Electronic address: nathan@dawnlight.com.
# Can't find a country for:
# Dawnlight Inc., China. Electronic address: erheng@dawnlight.com.
# Can't find a country for:
# Wenjing Tech Inc., China. Electronic address: qiaoranchen@wenjingtech.com.
# Can't find a country for:
# MISR Higher Institute for Engineering and Technology Egypt.
# Can't find a country for:
# Chr. Hansen A/S, Human Health Innovation, Hoersholm, Denmark.
# Can't find a country for:
# Department of Molecular Pharmacology, National Institute of Neuroscience, National Center of Neurology and Psychiatry, Kodaira, Japan. Electronic address: muramatsu@ncnp.go.jp.
# Can't find a country for:
# Technical Consultant at SoftV, U.K.
# Can't find a country for:
# Information Security and Networking Research Group (InFORSNET), Faculty of Information and Communication Technology, Universiti Teknikal Malaysia Melaka, Durian Tunggal, 76100, Malaysia. Electronic address: almohaiqny@gmail.com.
# Can't find a country for:
# G.tec Medical Engineering GmbH, Schiedlberg, Austria. Electronic address: guger@gtec.at.
# Can't find a country for:
# Stanford Artificial Intelligence in Medicine Centre, Stanford, CA, USA.
# Can't find a country for:
# SOLVD Health, Hershey, PA, USA dcardamone@solvdhealth.com.
# Can't find a country for:
# Division of Gastroenterology, Department of Internal Medicine, Dalin Tzu Chi Hospital, Buddhist Tzu Chi Medical Foundation, Chiayi 62247, Taiwan.
# Can't find a country for:
# Cape Regional Medical Center, Cape May Court House, NJ, United States. Electronic address: amccoy@caperegional.com.
# Can't find a country for:
# Heart Input Output, Inc. DBA HEARTio.
# Can't find a country for:
# Google Health via Vituity, Emeryville, CA, USA.
# Can't find a country for:
# School of Computer Science, Canadian International College (CIC), Egypt.
# Can't find a country for:
# UCLA-Olive View Internal Medicine Residency Program, Sylmar, CA, USA. law.jade@gmail.com.
# Can't find a country for:
# UCLA-Olive View Internal Medicine Residency Program, Sylmar, CA, USA.
# Can't find a country for:
# UCLA-Olive View Internal Medicine Residency Program, Sylmar, CA, USA.
# Can't find a country for:
# Department of Biomedical EngineeringCase Western Reserve UniversityClevelandOH44106USA.
# Can't find a country for:
# The Tony and Leona Campane Center for Excellence in Image-Guided Surgery and Advancing Imaging ResearchCleveland Clinic Cole Eye InstituteClevelandOH44106USA.
# Can't find a country for:
# Department of Biomedical EngineeringCase Western Reserve UniversityClevelandOH44106USA.
# Can't find a country for:
# The Tony and Leona Campane Center for Excellence in Image-Guided Surgery and Advancing Imaging ResearchCleveland Clinic Cole Eye InstituteClevelandOH44106USA.
# Can't find a country for:
# Department of Biomedical EngineeringCase Western Reserve UniversityClevelandOH44106USA.
# Can't find a country for:
# The Tony and Leona Campane Center for Excellence in Image-Guided Surgery and Advancing Imaging ResearchCleveland Clinic Cole Eye InstituteClevelandOH44106USA.
# Can't find a country for:
# Departments of Neurosurgery (L.M.P., G.A.G.).
# Can't find a country for:
# Neurology (P.G.F.).
# Can't find a country for:
# Departments of Neurosurgery (L.M.P., G.A.G.).
# Can't find a country for:
# Department of Public Health Sciences, Penn State Cancer Institute, PA, United States. Electronic address: mwang@phs.psu.edu.
# Can't find a country for:
# The First People's Hospital of Yunnan Province, China. Electronic address: lw13908701155@163.com.
# Can't find a country for:
# Department of Surgical Gastroenterology and Transplantation, Rigshospitalet; Center for Surgical Translational and Artificial Intelligence Research, Rigshospitalet.
# Can't find a country for:
# Department of Surgical Gastroenterology and Transplantation, Rigshospitalet; Center for Surgical Translational and Artificial Intelligence Research, Rigshospitalet.
# Can't find a country for:
# International Interdisciplinary Consensus Committee on DDH Evaluation (ICODE), Heraklion, Greece. akarantanas@gmail.com.
# Can't find a country for:
# DuPage Medical Group, Radiology. Electronic address: ayis@ayis.org.
# Can't find a country for:
# DuPage Medical Group, Radiology.
# Can't find a country for:
# DuPage Medical Group, Radiology.
# Can't find a country for:
# Department of Management Science and Engineering, Stanford School of Engineering, Stanford, CA, USA.
# Can't find a country for:
# Division of Pediatric Endocrinology, Stanford School of Medicine, Stanford, CA, USA; Lucile Packard Children's Hospital, Stanford, CA, USA.
# Can't find a country for:
# Division of Pediatric Endocrinology, Stanford School of Medicine, Stanford, CA, USA; Lucile Packard Children's Hospital, Stanford, CA, USA; Stanford Diabetes Research Center, Stanford School of Medicine, Stanford, CA, USA; Department of Health Research and Policy, Stanford School of Medicine, Stanford, CA, USA.
# Can't find a country for:
# Department of Management Science and Engineering, Stanford School of Engineering, Stanford, CA, USA; Division of Pediatric Endocrinology, Stanford School of Medicine, Stanford, CA, USA; Lucile Packard Children's Hospital, Stanford, CA, USA; Stanford Diabetes Research Center, Stanford School of Medicine, Stanford, CA, USA; Clinical Excellence Research Center, Stanford School of Medicine, Stanford, CA, USA. Electronic address: dscheink@stanford.edu.
# Can't find a country for:
# Radiology Department, Hospital Universitarioy Polite'cnico La Fe and Biomedical Imaging Research Group (GIBI230).
# Can't find a country for:
# General Electric Healthcare, 78530 Buc, France. Electronic address: nicolas.gogin@ge.com.
# Can't find a country for:
# CardioIntelligence Inc.
# Can't find a country for:
# Department of Math and Computer Science, Weizmann Institute of Science, Rehovot, Israel. yonina.eldar@weizmann.ac.il.
# Can't find a country for:
# Department of Mathematical & Statistical Sciences.
# Can't find a country for:
# Department of Mathematical & Statistical Sciences.
# Can't find a country for:
# General Electric Healthcare, 78530 Buc, France. Electronic address: adele.courot@ge.com.
# Can't find a country for:
# Department of Data Systems, 3D Medicines Inc.
# Can't find a country for:
# Department of Data Systems, 3D Medicines Inc.
# Can't find a country for:
# Department of Pathology, 3D Medicines Inc.
# Can't find a country for:
# Department of Data Systems, 3D Medicines Inc.
# Can't find a country for:
# Departments of Psychiatry and of Child Study, Yale School of Medicine, United States of America. Electronic address: sarah.yip@yale.edu.
# Can't find a country for:
# Department of Diagnostic Radiology, Osaka City General Hospital, 2-13-22 Miyakojima-hondori, Miyakojima-ku, Osaka, 534-0021, Japan. o-kuma@msic.osaka-cu.ac.jp.
# Can't find a country for:
# People's Hospital of Xinjiang Uygur Autonomous Region, 91 Tianchi Road, Ophthalmology, Urumqi, 830001, China. 17865815367@163.com.
# Can't find a country for:
# Department of Computer Science and EngineeringUniversity of RajshahiRajshahi6205Bangladesh.
# Can't find a country for:
# Department of Mathematics and StatisticsImam Muhammad Ibn Saud Islamic UniversityRiyadh13318Saudi Arabia.
# Can't find a country for:
# Bone Biology DivisionGarvan Institute of Medical ResearchDarlinghurstNSW2010Australia.
# Can't find a country for:
# WHO Collaborating Centre of eHealth, School of Public Health and Community MedicineUniversity of New South WalesSydneyNSW2052Australia.
# Can't find a country for:
# IBM Research, Rueschlikon, Switzerland.
# Can't find a country for:
# Graduate School of Science and Technology, Nara Insitute of Science and Technology, Japan. Electronic address: alex-mhuang@is.naist.jp.
# Can't find a country for:
# Departments of1Neurosurgery and.
# Can't find a country for:
# Departments of1Neurosurgery and.
# Can't find a country for:
# Departments of1Neurosurgery and.
# Can't find a country for:
# Institute of Visual Computing and Human-Centered Technology, TU Wien, Austria; VRVis Research Center, Austria. Electronic address: groeller@cg.tuwien.ac.at.
# Can't find a country for:
# Arab Academy for Science, Technology, and Maritime Transport, Egypt.
# Can't find a country for:
# National Institute of Research and Development for Optoelectronics - INOE 2000, Magurele, Romania. Electronic address: micalin@inoe.ro.
# Can't find a country for:
# Lunit Incorporated.
# Can't find a country for:
# Fujifilm Corporation, Japan. Electronic address: atsushi.tachibana@fujifilm.com.
# Can't find a country for:
# Fujifilm Corporation, Japan. Electronic address: takuya.fuchigami@fujifilm.com.
# Can't find a country for:
# Fujifilm Corporation, Japan. Electronic address: sadato.akahori@fujifilm.com.
# Can't find a country for:
# Google Health via Advanced Clinical.
# Can't find a country for:
# Google Health via Advanced Clinical.
# Can't find a country for:
# Department of Epidemiology and Biostatistics.
# Can't find a country for:
# Data used in preparation of this article were obtained from the Alzheimer's Disease Neuroimaging Initiative (ADNI) database (adni.loni.usc.edu). As such, the investigators within the ADNI contributed to the design and implementation of ADNI and/or provided data but did not participate in analysis or writing of this report. A complete listing of ADNI investigators can be found at: http://adni.loni.usc.edu/wp-content/uploads/how_to_apply/ADNI_Acknowledgement_List.pdf.
# Can't find a country for:
# Data used in the preparation of this article was obtained from the Australian Imaging Biomarkers and Lifestyle Flagship Study of Ageing (AIBL) funded by the Commonwealth Scientific and Industrial Research Organisation (CSIRO) which was made available at the ADNI database. The AIBL researchers contributed data but did not participate in analysis or writing of this report. AIBL researchers are listed at www.aibl.csiro.au.
# Can't find a country for:
# Institute of Computational Biology, Helmholtz Zentrum München-German Research Center for Environmental Health, Neuherberg, Germany. carsten.marr@helmholtz-muenchen.de.
# Can't find a country for:
# Hikvision Digital Technology Company Limited, Hangzhou310051, China.
# Can't find a country for:
# Hikvision Digital Technology Company Limited, Hangzhou310051, China. Electronic address: pushiliang.hri@hikvision.com.
# Can't find a country for:
# Hikvision Digital Technology Company Limited, Hangzhou310051, China.
# Can't find a country for:
# National Clinical Research Center for Child Health, China. Electronic address: shuqiang@zju.edu.cn.
# Can't find a country for:
# Department of Neurology, Penn State Hershey Medical Center, Hershey, PA, United States; Department of Radiology, Penn State Hershey Medical Center, Hershey, PA, United States. Electronic address: guangweidu@pennstatehealth.psu.edu.
# Can't find a country for:
# Department of Electronic Science and TechnologyUniversity of Science and Technology of ChinaHefei230027China.
# Can't find a country for:
# Department of ElectrocardiogramThe First Affiliated Hospital of USTC, Division of Life Sciences and MedicineUniversity of Science and Technology of ChinaHefei230001China.
# Can't find a country for:
# Department of Electronic Science and TechnologyUniversity of Science and Technology of ChinaHefei230027China.
# Can't find a country for:
# Department of Electronic Engineering and Information ScienceUniversity of Science and Technology of ChinaHefei230027China.
# Can't find a country for:
# Department of Neonatology, Xinjiang Uigur Municipal People's Hospital, Urumqi 830001, China.
# Can't find a country for:
# SimulaMet0167OsloNorway.
# Can't find a country for:
# SimulaMet0167OsloNorway.
# Can't find a country for:
# SimulaMet0167OsloNorway.
# Can't find a country for:
# Novartis Pharma AG, Switzerland. Electronic address: alexandros.sagkriotis@novartis.com.
# Can't find a country for:
# IQVIA Real World Insights, Switzerland.
# Can't find a country for:
# Department of Gastrointestinal Medical Oncology, Jiangxi Provincial Cancer Hospital, Nangchang, China.
# Can't find a country for:
# Department of Gastrointestinal Medical Oncology, Jiangxi Provincial Cancer Hospital, Nangchang, China.
# Can't find a country for:
# Department of Radiology, Honghu People's Hospital, Honghu, Hubei 433220, China.
# Can't find a country for:
# xRapid-Group, 13100 Aix en Provence, France; dmendels@me.com laurent.dortet@aphp.fr.
# Can't find a country for:
# Medcurio.
# Can't find a country for:
# Department of Pathology, Surgical Pathology, Stanford, CA, USA.
# Can't find a country for:
# Department of Ophthalmology, Casey Eye Institute and campbelp@ohsu.edu.
# Can't find a country for:
# Division of Epidemiology, and.
# Can't find a country for:
# Division of Epidemiology, and.
# Can't find a country for:
# Department of Immunobiology.
# Can't find a country for:
# The Hartree Centre, Sci-Tech Daresbury, IBM Research, Daresbury, WA4 4AD, UK. acarrieri@uk.ibm.com.
# Can't find a country for:
# Unilever Research and Development, Sharnbrook, MK44 1LQ, UK.
# Can't find a country for:
# Center for Intelligent Systems, EPFL, Switzerland. Electronic address: dorina.thanou@epfl.ch.
# Can't find a country for:
# Google.org, https://www.google.org, USA.
# Can't find a country for:
# Google.org, https://www.google.org, USA.
# Can't find a country for:
# Google.org, https://www.google.org, USA.
# Can't find a country for:
# Google.org, https://www.google.org, USA.
# Can't find a country for:
# Department of Orthopedics Trauma and Hand Surgery.
# Can't find a country for:
# Department of Orthopedics Trauma and Hand Surgery.
# Can't find a country for:
# Heart and Vascular Center, Evangelical Hospital, Lewisburg, PA (J.M.P.).
# Can't find a country for:
# Arab Academy for Science and Technology, Egypt.
# Can't find a country for:
# Faculdade de Ciências Exatas e da Engenharia, Universidade da Madeira, Portugal; ITI/Larsys/Madeira Interactive Technologies Institute, Portugal. Electronic address: morgado@uma.pt.
# Can't find a country for:
# Division of Digital Health Sciences, Mayo Clinic, MN, USA; Department of Health Sciences Research, Mayo Clinic, MN, USA. Electronic address: Wang.Yanshan@mayo.edu.
# Can't find a country for:
# Division of Clinical Infectious Diseases, Research Center Borstel, Borstel, Germany jheyckendorf@fz-borstel.de.
# Can't find a country for:
# German Center for Infection Research (DZIF), Germany.
# Can't find a country for:
# EEG Section, Office of the Clinical Director, NINDS, National Institutes of Health, United States. Electronic address: sara.inati@nih.gov.
# Can't find a country for:
# Department of Computer Science and EngineeringUniversity of RajshahiRajshahi6205Bangladesh.
# Can't find a country for:
# Faculty of Medicine, School of PsychiatryUniversity of New South WalesSydneyNSW2052Australia.
# Can't find a country for:
# Department of Mathematics and StatisticsImam Mohammad Ibn Saud Islamic UniversityRiyadh11432Saudi Arabia.
# Can't find a country for:
# Garvan Institute of Medical ResearchDarlinghurstNSW2010Australia.
# Can't find a country for:
# Faculty of Medicine, School of PsychiatryUniversity of New South WalesSydneyNSW2052Australia.
# Can't find a country for:
# Department of Orthopedic Surgery, Eniwa Hospital, Koganechuo 2-1-1, Eniwa, Hokkaido 061-1449, Japan.
# Can't find a country for:
# See Acknowledgments, .
# Can't find a country for:
# Comprehensive Breast Cancer Center, Changhua Christian Hospital, Changhua, Taiwan. darren.chen@cch.org.tw.
# Can't find a country for:
# Nuclear Medicine Unit, Fondazione Istituto G. Giglio, Contrada Pietrapollastra Pisciotto, 90015, Cefalù, PA, Italy. alongi.pierpaolo@gmail.com.
# Can't find a country for:
# Stanford Clinical Excellence Research Center, Stanford, CA, USA.
# Can't find a country for:
# Department of Pediatrics (Neonatology), Biomedical Research and Innovation Institute of Cádiz (INiBICA) Research Unit, Puerta del Mar Hospital, Ana de Viya Avenue 21, 11009, Cádiz, Spain. isabel.benavente.sspa@juntadeandalucia.es.
# Can't find a country for:
# Department of Neurology I.C., Oasi Research Institute - IRCCS, Troina, Italy. Electronic address: rferri@oasi.en.it.
# Can't find a country for:
# Supernus Pharmaceuticals, Inc.
# Can't find a country for:
# Supernus Pharmaceuticals, Inc.. Electronic address: anasser@supernus.com.
# Can't find a country for:
# Department of Clinical Investigation, Nordsjællands Hospital, Hillrød, Denmark.
# Can't find a country for:
# Research and Practical Clinical Center for Diagnostics and Telemedicine Technologies.
# Can't find a country for:
# Research and Practical Clinical Center for Diagnostics and Telemedicine Technologies.
# Can't find a country for:
# Skolkovo Institute of Science and Technology; Kharkevich Institute for Information Transmission Problems.
# Can't find a country for:
# Research and Practical Clinical Center for Diagnostics and Telemedicine Technologies.
# Can't find a country for:
# Research and Practical Clinical Center for Diagnostics and Telemedicine Technologies.
# Can't find a country for:
# Tri-Institutional Center for Translational Research in Neuroimaging and Data Science (TReNDS).
# Can't find a country for:
# Department of Computer ScienceSwansea UniversitySwanseaSA1 8ENU.K.
# Can't find a country for:
# Department of Computer ScienceSwansea UniversitySwanseaSA1 8ENU.K.
# Can't find a country for:
# Dept. of Electronic and Electrical Communication Engineering, Al-Obour High Institute for Engineering and Technology, Egypt.
# Can't find a country for:
# School of Biomedical Informatics.
# Can't find a country for:
# School of Biomedical Informatics.
# Can't find a country for:
# School of Biomedical Informatics.
# Can't find a country for:
# Molecular Medicine Laboratory, Department of Research, Changhua Christian Hospital, 8F., No. 235, XuGuang Road, Changhua, Taiwan. Electronic address: weichung.shia@gmail.com.
# Can't find a country for:
# Comprehensive Breast Cancer Center, Changhua Christian Hospital, No. 135, NanXiao Street, Changhua, Taiwan. Electronic address: darren.chen@cch.org.tw.
# Can't find a country for:
# Institute of Bioelectronic Medicine, Feinstein Institutes for Medical Research, Northwell Health, Manhasset, NY, USA. tzanos@northwell.edu.
# Can't find a country for:
# Department of Radiology, Shamir Medical Center, Zerifin.
# Can't find a country for:
# Department of Radiology, Shamir Medical Center, Zerifin.
# Can't find a country for:
# Department of Interventional Neuroradiology, Shamir Medical Center, Zerifin, Israel.
# Can't find a country for:
# Department of Radiology, Shamir Medical Center, Zerifin.
# Can't find a country for:
# Sunovion Pharmaceuticals Inc, USA. Electronic address: seth.hopkins@sunovion.com.
# Can't find a country for:
# Department of Information EngineeringUniversità Politecnica delle Marche60131AnconaItaly.
# Can't find a country for:
# Federazione Italiana Medici di Medicina Generale (FIMMG)00144RomeItaly.
# Can't find a country for:
# Department of Information EngineeringUniversità Politecnica delle Marche60131AnconaItaly.
# Can't find a country for:
# Département de génie logiciel et des TI, École de technologie supérieure.
# Can't find a country for:
# YIWEI Medical Technology Co., Ltd, Room 1001, MAI KE LONG Building, Nanshan, ShenZhen, 518000, China. lawrence.wang@szdrbrain.com.
# Can't find a country for:
# TexiSense, France.
# Can't find a country for:
# MondoBrain.
# Can't find a country for:
# Departments of Psychiatry and of Child Study, Yale School of Medicine, United States. Electronic address: sarah.yip@yale.edu.
# Can't find a country for:
# Laboratorio de Comunicación Celular y Dinámica Vascular, Departamento de Ciencias Básicas, Facultad de Ciencias, Universidad del Bío-Bio, Chile; Group of Research and Innovation in Vascular Health (GRIVAS-Health), Chile.
# Can't find a country for:
# Richard and Loan Hill Department of BioengineeringUniversity of Illinois at ChicagoChicagoIL60607USA.
# Can't find a country for:
# Department of MedicineUniversity of Illinois at ChicagoChicagoIL60612USA.
# Can't find a country for:
# Richard and Loan Hill Department of BioengineeringUniversity of Illinois at ChicagoChicagoIL60607USA.
# Can't find a country for:
# Department of Diagnostic Radiology, Chang Gung Memorial Hospital Chiayi Branch, Chiayi, Taiwan. chienwei33@gmail.com.
# Can't find a country for:
# Department of Occupational Medicine, Epidemiology and Prevention, Northwell Health, 175 Community Drive, 2nd floor, Great Neck, NY 11021, USA; Department of Emergency Medicine, Long Island Jewish Medical Center, Northwell Health, 270-05 76th Ave, Queens, NY 11040, USA,. Electronic address: Evortsman1@northwell.edu.
# Can't find a country for:
# Department of Radiology, Massachusetts General Hospital and Harvard Medical School. Electronic address: Cai.Wenli@mgh.harvard.edu.
# Can't find a country for:
# Plateau de Microbiologie 24/24, Institut des Agents Infectieux, France.
# Can't find a country for:
# Plateau de Microbiologie 24/24, Institut des Agents Infectieux, France.
# Can't find a country for:
# Department of Diagnostic Radiology, Chang Gung Memorial Hospital Chiayi Branch, Chiayi, Taiwan. russell.tsai@gmail.com.
# Can't find a country for:
# Research Unit of Molecular Epidemiology, Helmholtz Zentrum München - German Research Center for Environmental Health, Neuherberg, Germany rui.wang-sattler@helmholtz-muenchen.de.
# Can't find a country for:
# Department of Surgery, Donald and Barbara Zucker School of Medicine at Hofstra/Northwell, Manhasset, NY; Divisions of Vascular and Endovascular Surgery, Donald and Barbara Zucker School of Medicine at Hofstra/Northwell, Manhasset, NY. Electronic address: fmussa@northwell.edu.
# Can't find a country for:
# Indian Institute of Technology HyderabadHyderabad502205India.
# Can't find a country for:
# RMIT UniversityMelbourneVIC3001Australia.
# Can't find a country for:
# Indian Institute of Technology HyderabadHyderabad502205India.
# ...
# Can't find a country for:
# Medical Research Division, Korea Institute of Oriental Medicine, Deajeon, 305-811, Republic of Korea. ssmed@kiom.re.kr.
# Can't find a country for:
# Statistics, Global Innovative Pharma.
# Can't find a country for:
# Research & Development Department, Artelnics, Spain.
# Can't find a country for:
# UNAM, Pôle Recherche & Innovation, Fondation Ellen Poidatz, 1 Rue Ellen Poidatz, Saint-Fargeau-Ponthierry, France. Electronic address: eric.desailly@fondationpoidatz.com.
# Can't find a country for:
# Department of Cardiology, Nephrology and Endocrinology, Nordsjaellands Hospital, Hilleroed, Denmark.
# Can't find a country for:
# Division of Vascular Surgery, Stanford Health Care, Stanford, Calif. Electronic address: nleeper@stanford.edu.
# Can't find a country for:
# Jožef Stefan Institue, Jamova cesta 39, Slovenia. boza.cvetkovic@ijs.si.
# Can't find a country for:
# 2 Villa Beretta Rehabilitation Centre, Valduce Hospital, Costamasnaga, Italy.
# Can't find a country for:
# Department of Psychiatry, Icahn School of Medicine at Mount Sinai, USA. Electronic address: sophia.frangou@mssm.edu.
# Can't find a country for:
# INESC-ID, Portugal.
# Can't find a country for:
# Department of Electrical and Electronic Engineering, Universiti Putra Malaysia, 43400, Serdang, Malaysia. eng.mgd@gmail.com.
# Can't find a country for:
# National Institute of Mental Health,Klecany,Czech Republic.
# Can't find a country for:
# National Institute of Mental Health,Klecany,Czech Republic.
# Can't find a country for:
# MIT Computer Science And Artificial Intelligence Laboratory, Tel.: +1-617-800-3033, souillardmandar@csail.mit.edu.
# Can't find a country for:
# MIT Computer Science And Artificial Intelligence Laboratory, Tel.: +1-617-253-5879, davis@csail.mit.edu.
# Can't find a country for:
# MIT Computer Science And Artificial Intelligence Laboratory, rudin@mit.edu.
# Can't find a country for:
# Intermountain Healthcare Cardiovascular Clinical Program.
# Can't find a country for:
# Intermountain Healthcare Cardiovascular Clinical Program.
# Can't find a country for:
# McKay Dee Hospital Cardiovascular Program.
# Can't find a country for:
# Medial-Research, Kfar Malal, Israel pini@medial-research.com.
# Can't find a country for:
# Computer Science and Artificial Intelligence Lab, EECS, MIT.
# Can't find a country for:
# Computer Science and Artificial Intelligence Lab, EECS, MIT.
# Can't find a country for:
# CSIRO Health and Biosecurity, The Australian e-Health & Research Centre, Herston, QLD, Australia. Electronic address: kaikai.shen@csiro.au.
# Can't find a country for:
# CSIRO Health and Biosecurity, The Australian e-Health & Research Centre, Herston, QLD, Australia. Electronic address: pierrick.bourgeat@csiro.au.
# Can't find a country for:
# CSIRO Health and Biosecurity, The Australian e-Health & Research Centre, Herston, QLD, Australia. Electronic address: jurgen.fripp@csiro.au.
# Can't find a country for:
# CSIRO Health and Biosecurity, The Australian e-Health & Research Centre, Herston, QLD, Australia. Electronic address: olivier.salvado@csiro.au.
# Can't find a country for:
# CSIRO Health and Biosecurity, The Australian e-Health & Research Centre, Herston, QLD, Australia. Electronic address: stephen.rose@csiro.au.
# Can't find a country for:
# CCG, Computer Graphics Center, Portugal. Electronic address: mguevara@ccg.pt.
# Can't find a country for:
# Immunology Department, Weizmann Institute of Science, Rehovot 7610001, Israel. Electronic address: eran.elinav@weizmann.ac.il.
# Can't find a country for:
# Department of Computer Science and Applied Mathematics, Weizmann Institute of Science, Rehovot 7610001, Israel; Department of Molecular Cell Biology, Weizmann Institute of Science, Rehovot 7610001, Israel. Electronic address: eran.segal@weizmann.ac.il.
# Can't find a country for:
# Department of Information Engineering, Università degli Studi di Firenze, Firenze, Italy. Electronic address: claudia.manfredi@unifi.it.
# Can't find a country for:
# Technical Research Centre for Dependency Care and Autonomous Living(CETpD), Universitat Politcnica de Catalunya, Vilanova i la Geltr, Spain.
# Can't find a country for:
# Technical Research Centre for Dependency Care and Autonomous Living(CETpD), Universitat Politcnica de Catalunya, Vilanova i la Geltr, Spain.
# Can't find a country for:
# U.S. Department of Health and Human Services, United States. Electronic address: swain.matthew@gmail.com.
# Can't find a country for:
# Graduate Institute of Biomedical Informatics.
# Can't find a country for:
# Departments of Biomedical Informatics, and michael.w.temple@vanderbilt.edu mtemple1@me.com.
# Can't find a country for:
# Australian e-Health Research Centre, CSIRO, Digital Productivity Flagship.
# Can't find a country for:
# Department of Radiology and Dalio Institute of Cardiovascular Imaging, Weill Cornell Medical College, 10021 NY, USA. Electronic address: gux2003@med.cornell.edu.
# Can't find a country for:
# Dalio Institute of Cardiovascular Imaging NewYork-Presbyterian Hospital and Weill Cornell Medical College, 10021 NY, USA. Electronic address: dek2016@med.cornell.edu.
# Can't find a country for:
# Dalio Institute of Cardiovascular Imaging NewYork-Presbyterian Hospital and Weill Cornell Medical College, 10021 NY, USA. Electronic address: kie2001@med.cornell.edu.
# Can't find a country for:
# Dalio Institute of Cardiovascular Imaging NewYork-Presbyterian Hospital and Weill Cornell Medical College, 10021 NY, USA. Electronic address: ikc2001@med.cornell.edu.
# Can't find a country for:
# Dalio Institute of Cardiovascular Imaging NewYork-Presbyterian Hospital and Weill Cornell Medical College, 10021 NY, USA. Electronic address: jkm2001@med.cornell.edu.
# Can't find a country for:
# Institute for Neural Computation, and.
# Can't find a country for:
# Finnish Geospatial Research Institute, Geodeetinrinne 2, FI-02430 Masala, Finland. robert.guinness@nls.fi.
# Can't find a country for:
# Faculty of Computer Engineering, IAU, Shabestar Branch, Iran. Electronic address: alifarzanam@gmail.com.
# Can't find a country for:
# Electronics and Communication Sciences Unit, Indian Statistical Institute, Calcutta 700108 and.
# Can't find a country for:
# Electronics and Communication Sciences Unit, Indian Statistical Institute, Calcutta 700108 and.
# Can't find a country for:
# Medical Research Division, Korea Institute of Oriental Medicine, 1672 Yuseongdae-ro, Yuseong-gu, Deajeon 305-811, Republic of Korea. Electronic address: jupiter-lee@hanmail.net.
# Error parsing Mental Health Center-Duhok,Kurdistan Region,Iraq., trying again for a maximum of 5 times.
# Error parsing Mental Health Center-Duhok,Kurdistan Region,Iraq., trying again for a maximum of 5 times.
# Can't find a country for:
# Mental Health Center-Duhok,Kurdistan Region,Iraq.
# Can't find a country for:
# Clinical Image Processing Service, Radiology and Imaging Sciences, NIH, United States. Electronic address: JYao@cc.nih.gov.
# Can't find a country for:
# Medical System Lab.
# Can't find a country for:
# School of Mechatronic Engineering, Universiti Malaysia Perlis (UniMAP), 02600, Campus Pauh Putra, Perlis, Malaysia. Electronic address: hari@unimap.edu.my.
# Can't find a country for:
# Genome Institute, National Center for Genetic Engineering and Biotechnology, Pathumtani, Thailand. Electronic address: sissades@biotec.or.th.
# Can't find a country for:
# Neuroimaging Research Unit, Institute of Neurological Sciences, National Research Council, Germaneto, CZ, Italy. Electronic address: a.cerasa@unicz.it.
# Can't find a country for:
# Institute for Bioengineering of Catalonia and Universitat Politecnica de Catalunya, BarcelonaTech, Spain(2). Electronic address: alicia.casals@upc.edu.
# Can't find a country for:
# Department of Commerce Automation and Management, National Pingtung Institute of Commerce, No. 51, Min Sheng E. Road, Pingtung, 900, Taiwan, Republic of China, d917812@oz.nthu.edu.tw.
# Can't find a country for:
# Faculty of computers and Information, Benha university, Benha, Egypt. ahmad_T_azar@ieee.org
# Can't find a country for:
# IBM T. J. Watson Research Center, Yorktown Heights, NY, United States. Electronic address: roybyrd@us.ibm.com.
# Can't find a country for:
# IIIA-Artificial Intelligence Research Institute, Spanish National Research Council, Campus UAB s/n, Bellaterra, Catalonia, Spain. eva@iiia.csic.es
# Can't find a country for:
# Department of Nuclear Medicine, Chang Bing Show Chwan Memorial Hospital, Changhua, Taiwan (JSC)
# Can't find a country for:
# Carl.Berdahl@verizon.net
# Can't find a country for:
# Bio-IT Center, NEC Corporation. rteramotjp@gmail.com
# 100%|██████████████████████████████████████████████████████████████████████████| 34179/34179 [4:38:02<00:00,  2.05it/s]

# %%
articles.tail(25)
# Out:
#            pmid  doi                                              title  \
# 172411  9508109  NaN  Prediction and cross-validation of neural netw...
# 172422  9466835  NaN         Modeling obesity using abductive networks.
# 172432  9505252  NaN  A neural net representation of experienced and...
# 172437  9495724  NaN  Use of a neural network to predict stone growt...
# 172450  9481717  NaN  An artificial neural network can select patien...
# 172451  9481716  NaN  Application of Kohonen neural networks for the...
# 172457  9479345  NaN  Neural-network-assisted analysis and microscop...
# 172469  9473995  NaN  Recognition of daily life motor activity class...
# 172477  9470397  NaN  Non-parametric classification of esophagus mot...
# 172478  9470396  NaN  Decision support for psychiatric diagnosis bas...
# 172492  9431637  NaN  Classification of low back pain from dynamic m...
# 172495  9458164  NaN  Improving morphology-based malignancy grading ...
# 172498  9457438  NaN  Ventilation mode recognition using artificial ...
# 172499  9457435  NaN  Automated detection of hereditary syndromes us...
# 172503  9456211  NaN  Neural network assessment of perioperative car...
# 172509  9453525  NaN  TACHY: an expert system for the management of ...
# 172515  9450258  NaN     Detection of ECG waveforms by neural networks.
# 172519  9445150  NaN  Neural network analysis of breast cancer from ...
# 172520  9440819  NaN  Automated classification of patients with chro...
# 172523  9438272  NaN  On the use of neural network techniques to ana...
# 172524  9438271  NaN  Analysis of quantitative EEG with artificial n...
# 172526  9436967  NaN  Neural networks as a prognostic tool for patie...
# 172530  9430460  NaN  Automated interpretation of myocardial SPECT p...
# 172537  9423655  NaN  Acute pulmonary embolism: cost-effectiveness a...
# 172538  9415600  NaN  Algorithm analysis of lectin glycohistochemist...
#
#                                                  abstract article_date  \
# 172411  The authors developed and cross-validated pred...          NaN
# 172422  This paper investigates the use of abductive-n...          NaN
# 172432  A neural net approach was used to classify and...          NaN
# 172437  To determine whether a neural network is super...          NaN
# 172450  The object of the study was to develop an arti...          NaN
# 172451  A Kohonen topological map is an artificial int...          NaN
# 172457  To compare cytologists' detection of abnormali...          NaN
# 172469  To investigate a possible role of artificial n...          NaN
# 172477  Automatic long-term recording of esophageal pr...          NaN
# 172478  This paper compares two classifiers: Pseudo Ba...          NaN
# 172492  Data were collected from 183 subjects who were...          NaN
# 172495  We propose an original methodology which impro...          NaN
# 172498  This study investigated the capabilities of ar...          NaN
# 172499  Computer-based data mining methodology applied...          NaN
# 172503  Neural networks were developed to predict peri...          NaN
# 172509  Many physicians find the management of suprave...          NaN
# 172515  In this study, ECG waveform detection was perf...          NaN
# 172519  To evaluate how much the experience of radiolo...          NaN
# 172520  The goal of this study was the discrimination ...          NaN
# 172523  This is the third communication on the use of ...          NaN
# 172524  Artificial neural networks (ANN) are widely us...          NaN
# 172526  Patients with non-small cell carcinoma of the ...          NaN
# 172530  The purpose of this study was to develop a com...          NaN
# 172537  To evaluate the cost-effectiveness of artifici...          NaN
# 172538  The aim of this study is to present a new clas...          NaN
#
#        pubmed_date       article_type lang  \
# 172411  1998-03-21  Comparative Study  eng
# 172422  1998-03-21  Comparative Study  eng
# 172432  1998-03-20     Clinical Trial  eng
# 172437  1998-03-12     Clinical Trial  eng
# 172450  1998-03-03    Journal Article  eng
# 172451  1998-03-03    Journal Article  eng
# 172457  1998-02-28     Clinical Trial  eng
# 172469  1998-02-25  Comparative Study  eng
# 172477  1998-02-21    Journal Article  eng
# 172478  1998-02-21  Comparative Study  eng
# 172492  1998-02-12    Journal Article  eng
# 172495  1998-02-11    Journal Article  eng
# 172498  1998-02-11     Clinical Trial  eng
# 172499  1998-02-11    Journal Article  eng
# 172503  1998-02-10    Journal Article  eng
# 172509  1998-02-07    Journal Article  eng
# 172515  1998-02-05    Journal Article  eng
# 172519  1998-01-28  Comparative Study  eng
# 172520  1998-01-24    Journal Article  eng
# 172523  1998-01-23     Clinical Trial  eng
# 172524  1998-01-23     Clinical Trial  eng
# 172526  1998-01-22    Journal Article  eng
# 172530  1998-01-16  Comparative Study  eng
# 172537  1998-01-10    Journal Article  eng
# 172538  1998-01-10    Journal Article  eng
#
#                                                   journal  \
# 172411                   American journal of epidemiology
# 172422  Computers and biomedical research, an internat...
# 172432  Journal of rehabilitation research and develop...
# 172437                                            Urology
# 172450  Nephrology, dialysis, transplantation : offici...
# 172451  Nephrology, dialysis, transplantation : offici...
# 172457                                    Acta cytologica
# 172469   Archives of physical medicine and rehabilitation
# 172477                 Methods of information in medicine
# 172478                 Methods of information in medicine
# 172492                                              Spine
# 172495              Brain pathology (Zurich, Switzerland)
# 172498  Computers and biomedical research, an internat...
# 172499  Computers and biomedical research, an internat...
# 172503  Medical decision making : an international jou...
# 172509                             American heart journal
# 172515                      Medical engineering & physics
# 172519                                 Radiation medicine
# 172520                                          Cytometry
# 172523                                 Neuropsychobiology
# 172524                                 Neuropsychobiology
# 172526  Modern pathology : an official journal of the ...
# 172530  Journal of nuclear medicine : official publica...
# 172537                                          Radiology
# 172538  The Annals of otology, rhinology, and laryngology
#
#                    journal_short  ... author_affils keywords  \
# 172411            Am J Epidemiol  ...           NaN      NaN
# 172422         Comput Biomed Res  ...           NaN      NaN
# 172432         J Rehabil Res Dev  ...           NaN      NaN
# 172437                   Urology  ...           NaN      NaN
# 172450   Nephrol Dial Transplant  ...           NaN      NaN
# 172451   Nephrol Dial Transplant  ...           NaN      NaN
# 172457                Acta Cytol  ...           NaN      NaN
# 172469     Arch Phys Med Rehabil  ...           NaN      NaN
# 172477           Methods Inf Med  ...           NaN      NaN
# 172478           Methods Inf Med  ...           NaN      NaN
# 172492     Spine (Phila Pa 1976)  ...           NaN      NaN
# 172495              Brain Pathol  ...           NaN      NaN
# 172498         Comput Biomed Res  ...           NaN      NaN
# 172499         Comput Biomed Res  ...           NaN      NaN
# 172503          Med Decis Making  ...           NaN      NaN
# 172509                Am Heart J  ...           NaN      NaN
# 172515              Med Eng Phys  ...           NaN      NaN
# 172519                Radiat Med  ...           NaN      NaN
# 172520                 Cytometry  ...           NaN      NaN
# 172523        Neuropsychobiology  ...           NaN      NaN
# 172524        Neuropsychobiology  ...           NaN      NaN
# 172526                Mod Pathol  ...           NaN      NaN
# 172530                J Nucl Med  ...           NaN      NaN
# 172537                 Radiology  ...           NaN      NaN
# 172538  Ann Otol Rhinol Laryngol  ...           NaN      NaN
#
#                                                mesh_terms  \
# 172411  [Algorithms, Health Maintenance Organizations,...
# 172422  [Adult, Algorithms, Blood Glucose, Blood Press...
# 172432  [Adult, Disabled Persons, Energy Metabolism, E...
# 172437  [Follow-Up Studies, Humans, Kidney Calculi, Li...
# 172450  [Adolescent, Adult, Aged, Female, Glomerulonep...
# 172451  [Adult, Aged, Humans, Kidney Diseases, Kidney ...
# 172457  [Automation, Carcinoma, Case-Control Studies, ...
# 172469  [Activities of Daily Living, Adult, Aged, Ampu...
# 172477  [Adult, Aged, Deglutition Disorders, Esophagea...
# 172478  [Affective Symptoms, Bayes Theorem, Decision S...
# 172492  [Adult, Female, Humans, Kinesis, Linear Models...
# 172495  [Adult, Artificial Intelligence, Astrocytoma, ...
# 172498  [Aged, Computer Simulation, Humans, Male, Midd...
# 172499  [Adult, Algorithms, Colorectal Neoplasms, Dise...
# 172503  [Bayes Theorem, Calibration, Heart Diseases, H...
# 172509  [Aged, Algorithms, Artificial Intelligence, Ex...
# 172515  [Bundle-Branch Block, Electrocardiography, Hum...
# 172519  [Adolescent, Adult, Aged, Breast Neoplasms, Di...
# 172520  [Antibodies, Antigens, CD, Artificial Intellig...
# 172523  [Algorithms, Electroencephalography, Electromy...
# 172524  [Alcoholism, Algorithms, Discriminant Analysis...
# 172526  [Adenocarcinoma, Antigens, Nuclear, Biomarkers...
# 172530  [Coronary Angiography, Coronary Disease, Femal...
# 172537  [Acute Disease, Angiography, Cost-Benefit Anal...
# 172538  [Algorithms, Coloring Agents, Decision Trees, ...
#
#                                          references_pmids  \
# 172411                                                NaN
# 172422                                                NaN
# 172432                                                NaN
# 172437                                                NaN
# 172450                                                NaN
# 172451                                                NaN
# 172457                                                NaN
# 172469                                                NaN
# 172477                                                NaN
# 172478                                                NaN
# 172492                                                NaN
# 172495  [3395959, 2990664, 8586464, 8396854, 8534336, ...
# 172498                                                NaN
# 172499                                                NaN
# 172503                                                NaN
# 172509                                                NaN
# 172515                                                NaN
# 172519                                                NaN
# 172520                                                NaN
# 172523                                                NaN
# 172524                                                NaN
# 172526                                                NaN
# 172530                                                NaN
# 172537                                                NaN
# 172538                                                NaN
#
#                                                   feature include  \
# 172411  Prediction and cross-validation of neural netw...     1.0
# 172422  Modeling obesity using abductive networks. Thi...     1.0
# 172432  A neural net representation of experienced and...     1.0
# 172437  Use of a neural network to predict stone growt...     1.0
# 172450  An artificial neural network can select patien...     1.0
# 172451  Application of Kohonen neural networks for the...     1.0
# 172457  Neural-network-assisted analysis and microscop...     1.0
# 172469  Recognition of daily life motor activity class...     1.0
# 172477  Non-parametric classification of esophagus mot...     1.0
# 172478  Decision support for psychiatric diagnosis bas...     1.0
# 172492  Classification of low back pain from dynamic m...     1.0
# 172495  Improving morphology-based malignancy grading ...     1.0
# 172498  Ventilation mode recognition using artificial ...     1.0
# 172499  Automated detection of hereditary syndromes us...     1.0
# 172503  Neural network assessment of perioperative car...     1.0
# 172509  TACHY: an expert system for the management of ...     1.0
# 172515  Detection of ECG waveforms by neural networks....     1.0
# 172519  Neural network analysis of breast cancer from ...     1.0
# 172520  Automated classification of patients with chro...     1.0
# 172523  On the use of neural network techniques to ana...     1.0
# 172524  Analysis of quantitative EEG with artificial n...     1.0
# 172526  Neural networks as a prognostic tool for patie...     1.0
# 172530  Automated interpretation of myocardial SPECT p...     1.0
# 172537  Acute pulmonary embolism: cost-effectiveness a...     1.0
# 172538  Algorithm analysis of lectin glycohistochemist...     1.0
#
#        affil_countries  affil_countries_unique affil_first_country  \
# 172411           [nan]                   [nan]                 NaN
# 172422           [nan]                   [nan]                 NaN
# 172432           [nan]                   [nan]                 NaN
# 172437           [nan]                   [nan]                 NaN
# 172450           [nan]                   [nan]                 NaN
# 172451           [nan]                   [nan]                 NaN
# 172457           [nan]                   [nan]                 NaN
# 172469           [nan]                   [nan]                 NaN
# 172477           [nan]                   [nan]                 NaN
# 172478           [nan]                   [nan]                 NaN
# 172492           [nan]                   [nan]                 NaN
# 172495           [nan]                   [nan]                 NaN
# 172498           [nan]                   [nan]                 NaN
# 172499           [nan]                   [nan]                 NaN
# 172503           [nan]                   [nan]                 NaN
# 172509           [nan]                   [nan]                 NaN
# 172515           [nan]                   [nan]                 NaN
# 172519           [nan]                   [nan]                 NaN
# 172520           [nan]                   [nan]                 NaN
# 172523           [nan]                   [nan]                 NaN
# 172524           [nan]                   [nan]                 NaN
# 172526           [nan]                   [nan]                 NaN
# 172530           [nan]                   [nan]                 NaN
# 172537           [nan]                   [nan]                 NaN
# 172538           [nan]                   [nan]                 NaN
#
#        affil_last_country
# 172411                NaN
# 172422                NaN
# 172432                NaN
# 172437                NaN
# 172450                NaN
# 172451                NaN
# 172457                NaN
# 172469                NaN
# 172477                NaN
# 172478                NaN
# 172492                NaN
# 172495                NaN
# 172498                NaN
# 172499                NaN
# 172503                NaN
# 172509                NaN
# 172515                NaN
# 172519                NaN
# 172520                NaN
# 172523                NaN
# 172524                NaN
# 172526                NaN
# 172530                NaN
# 172537                NaN
# 172538                NaN
#
# [25 rows x 22 columns]

# %%
articles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 34181 entries, 1.0 to 172538.0
# Data columns (total 81 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   pmid                    34179 non-null  float64
#  1   doi                     29547 non-null  object
#  2   title                   34178 non-null  object
#  3   abstract                34179 non-null  object
#  4   article_date            25954 non-null  object
#  5   pubmed_date             34179 non-null  object
#  6   article_type            34179 non-null  object
#  7   lang                    34179 non-null  object
#  8   journal                 34179 non-null  object
#  9   journal_short           34179 non-null  object
#  10  journal_country         34179 non-null  object
#  11  authors                 33377 non-null  object
#  12  author_affils           24189 non-null  object
#  13  keywords                18861 non-null  object
#  14  mesh_terms              25518 non-null  object
#  15  references_pmids        16504 non-null  object
#  16  feature                 34178 non-null  object
#  17  include                 34178 non-null  float64
#  18  mature                  34178 non-null  float64
#  19  algo_neural_net         34178 non-null  float64
#  20  algo_support_vector     34178 non-null  float64
#  21  algo_regression         34178 non-null  float64
#  22  algo_decision_tree      34178 non-null  float64
#  23  feat_xr                 34178 non-null  float64
#  24  feat_ct                 34178 non-null  float64
#  25  feat_mri                34178 non-null  float64
#  26  feat_eeg                34178 non-null  float64
#  27  feat_ecg                34178 non-null  float64
#  28  feat_emg                34178 non-null  float64
#  29  feat_us                 34178 non-null  float64
#  30  feat_echo               34178 non-null  float64
#  31  feat_histo              34178 non-null  float64
#  32  feat_oct                34178 non-null  float64
#  33  feat_mamm               34178 non-null  float64
#  34  feat_endoscop           34178 non-null  float64
#  35  feat_gene               34178 non-null  float64
#  36  feat_bio                34178 non-null  float64
#  37  feat_nlp                34178 non-null  float64
#  38  feat_ehr                34178 non-null  float64
#  39  subspec_icu             34178 non-null  float64
#  40  subspec_ed              34178 non-null  float64
#  41  spec_paeds              34178 non-null  float64
#  42  spec_id                 34178 non-null  float64
#  43  subspec_sepsis          34178 non-null  float64
#  44  subspec_cov19           34178 non-null  float64
#  45  subspec_dermca          34178 non-null  float64
#  46  spec_onc                34178 non-null  float64
#  47  subspec_lungca          34178 non-null  float64
#  48  subspec_brainca         34178 non-null  float64
#  49  subspec_gica            34178 non-null  float64
#  50  subspec_hepca           34178 non-null  float64
#  51  subspec_prosca          34178 non-null  float64
#  52  subspec_gynonc          34178 non-null  float64
#  53  subspec_haemonc         34178 non-null  float64
#  54  subspec_breastca        34178 non-null  float64
#  55  subspec_urology         34178 non-null  float64
#  56  spec_psych              34178 non-null  float64
#  57  spec_msk                34178 non-null  float64
#  58  spec_gi                 34178 non-null  float64
#  59  spec_hep                34178 non-null  float64
#  60  spec_resp               34178 non-null  float64
#  61  subspec_pneum           34178 non-null  float64
#  62  spec_neuro              34178 non-null  float64
#  63  subspec_epilep          34178 non-null  float64
#  64  subspec_cva             34178 non-null  float64
#  65  subspec_alzh            34178 non-null  float64
#  66  spec_cvs                34178 non-null  float64
#  67  subspec_ihd             34178 non-null  float64
#  68  subspec_hf              34178 non-null  float64
#  69  subspec_arrhyt          34178 non-null  float64
#  70  spec_dm                 34178 non-null  float64
#  71  subspec_retina          34178 non-null  float64
#  72  spec_haem               34178 non-null  float64
#  73  spec_obs                34178 non-null  float64
#  74  spec_renal              34178 non-null  float64
#  75  affil_countries         23821 non-null  object
#  76  affil_countries_unique  23821 non-null  object
#  77  affil_first_country     23821 non-null  object
#  78  affil_last_country      23796 non-null  object
#  79  affil_fill_country      34179 non-null  object
#  80  countries_lc            23821 non-null  object
# dtypes: float64(59), object(22)
# memory usage: 21.4+ MB

# %% [markdown]
# ## CLEAN

# %%
articles['affil_fill_country'] = articles['affil_first_country']

# %%
## using first affiliation as primary country
## fill first with data from last author, then with pubmed country metadata
articles['affil_fill_country'] = articles['affil_fill_country'].fillna(articles['affil_last_country'])
articles['affil_fill_country'] = articles['affil_fill_country'].fillna(articles['journal_country'])

articles['affil_fill_country'] = articles['affil_fill_country'].astype('string')

# %%
##clean countries
articles["affil_fill_country"].replace({"England": "United Kingdom", 
                                             "Wales": "United Kingdom", 
                                             "Scotland": "United Kingdom", 
                                             "China (Republic : 1949- )" : "Taiwan"}, inplace=True)

articles['affil_fill_country'].value_counts()
# Out:
# United States          12415
# China                   5305
# United Kingdom          2482
# South Korea             1327
# Germany                 1273
#                        ...
# Azerbaijan                 1
# Trinidad and Tobago        1
# Kazakhstan                 1
# Costa Rica                 1
# Palestine                  1
# Name: affil_fill_country, Length: 91, dtype: int64

# %%
##lowercasing list of ANY author
articles['countries_lc'] = articles['affil_countries_unique'].str.lower().fillna(np.nan)

#articles['countries_lc'] = articles['countries_lc'].fillna(articles['affil_fill_country']).str.lower().astype('string')

# %%
articles['countries_lc'].replace(np.nan, '', inplace=True)

# %%
lmic_list = ["afghanistan", "burundi", "burkina faso", "central african republic", "congo", "eritrea", 
             "ethiopia", "guinea", "gambia", "guinea-bissau", "liberia", "madagascar", "mali", "mozambique", "malawi", 
             "niger", "north korea", "democratic republic of korea", "rwanda", "sudan", "sierra leone", "somalia", "south sudan", "syrian arab republic", 
             "chad", "togo", "uganda", "yemen", "angola", "benin", "bangladesh", "belize", "bolivia", "bhutan", 
             "cote d'ivoire", "ivory coast", "cameroon", "congo", "comoros", "cabo verde", "djibouti", "algeria", "egypt", 
             "micronesia", "ghana", "honduras", "haiti", "indonesia", "india", "iran", "kenya", 
             "kyrgyz republic", "cambodia", "kiribati", "lao", "sri lanka", "lesotho", "morocco", "myanmar", "mongolia", 
             "mauritania", "nigeria", "nicaragua", "nepal", "pakistan", "philippines", "papua new guinea", 
             "west bank and gaza", "palestinbe", "senegal", "solomon islands", "el salvador", "sao tome", "eswatini", 
             "tajikistan", "timor-leste", "tunisia", "tanzania", "ukraine", "uzbekistan", "vietnam", "vanuatu", "samoa", 
             "zambia", "zimbabwe", "albania", "argentina", "armenia", "american samoa", "azerbaijan", "bulgaria", 
             "bosnia", "belarus", "brazil", "botswana", "china", "colombia", "costa rica", "cuba", 
             "dominica", "dominican republic", "ecuador", "fiji", "gabon", "georgia", "equatorial guinea", "grenada", 
             "guatemala", "guyana", "iraq", "jamaica", "jordan", "kazakhstan", "lebanon", "libya", "lucia", "moldova", 
             "maldives", "mexico", "marshall islands", "north macedonia", "montenegro", "mauritius", "malaysia", "namibia", 
             "panama", "peru", "paraguay", "romania", "russian federation", "russia", "serbia", "suriname", "thailand", "turkmenistan", 
             "tonga", "turkey", "tuvalu", "st. vincent", "grenadines", "kosovo", "south africa", "venezuela"]

# %%
lmic_lower_list = ["afghanistan", "burundi", "burkina faso", "central african republic", "congo", "eritrea", 
             "ethiopia", "guinea", "gambia", "guinea-bissau", "liberia", "madagascar", "mali", "mozambique", "malawi", 
             "niger", "north korea", "democratic republic of korea", "rwanda", "sudan", "sierra leone", "somalia", "south sudan", "syrian arab republic", 
             "chad", "togo", "uganda", "yemen", "angola", "benin", "bangladesh", "belize", "bolivia", "bhutan", 
             "cote d'ivoire", "ivory coast", "cameroon", "congo", "comoros", "cabo verde", "djibouti", "algeria", "egypt", 
             "micronesia", "ghana", "honduras", "haiti", "indonesia", "india", "iran", "kenya", 
             "kyrgyz republic", "cambodia", "kiribati", "lao", "sri lanka", "lesotho", "morocco", "myanmar", "mongolia", 
             "mauritania", "nigeria", "nicaragua", "nepal", "pakistan", "philippines", "papua new guinea", 
             "west bank and gaza", "palestinbe", "senegal", "solomon islands", "el salvador", "sao tome", "eswatini", 
             "tajikistan", "timor-leste", "tunisia", "tanzania", "ukraine", "uzbekistan", "vietnam", "vanuatu", "samoa", 
             "zambia", "zimbabwe"]

# %%
##flags for ANY author

#initiate
articles['lmic_author_flag'] = np.where(articles['countries_lc'].str.contains('iran'), "1", "0")
articles['lmic_author_lower_flag'] = np.where(articles['countries_lc'].str.contains('iran'), "1", "0")
articles['lmic_china_flag'] = np.where(articles['countries_lc'].str.contains('china'), "1", "0")

# %%
#use lists
for x in lmic_list:
    articles['lmic_author_flag'] = np.where(articles['countries_lc'].str.contains(x), "1", articles['lmic_author_flag'])
    
for y in lmic_lower_list:
    articles['lmic_author_lower_flag'] = np.where(articles['countries_lc'].str.contains(x), "1", articles['lmic_author_lower_flag'])

# %%
articles['pubmed_date'] = pd.to_datetime(articles['pubmed_date'])

# %%
## new column for year, and year+month
articles['year'] = articles['pubmed_date'].dt.year

# %%
articles.to_csv('data/final_raw.csv')
